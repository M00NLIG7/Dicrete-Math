# %% [markdown]
# # PIE (The principal of inclusion and exclusion):
# $n(A\cup B)=n(A)+n(B)-n(A\cap B)$
#
# $n(A\cup B\cup C) = n(A)+n(B)+ n(C)-n(A\cap B)-n(A\cap C)-n(B\cap C)+n(A\cap B\cap C)$
#
# Counting with PIE
#
# Three people share 11 cookie. How many ways to distribute the cookies such that nobody gets more than 4 cookies?
#
# ⭐⭐⭐⭐⭐|⭐⭐⭐⭐⭐⭐ not allowable
#
# Goal: Total count = ${{11+2}\choose 2} - (\text{at least one gets 4 cookies})$ = nobody gets >4 cookies
#
# A = # nu ber of ways alberto gets >4
#
# $$|A\cap B| = |\{11-2*5=1 \text{ cookie}\}| = {{2+1}\choose 1} = |B\cap C| = |A\cap C|$$
#
# $$Total - (\text {At least one gets > 4}) = {13\choose 2} - (3*{8\choose 2} - 3*{3\choose 1}) = 3$$
#
# STEPS:
# 1) Question was hard, instead we counted the opposite of what was asked
# 2) Used PIE to do 1
# 3) Answer we want = $(Total) - \text{(What we dont want)}$
#
#
# Ex 1.6.2:
#
# 10 cookies stars
#
# 4 People Bars
#
# Nobody gets > 2 cookies
#
# ${Total count} = {{10+3}\choose 3} = {13\choose 3}$
#
#
# $${|A\cup B\cup C \cup D|} = |A|{4\choose 1} - {4\choose 2} {|A\cap B|} + {4\choose 3} {|A\cap B \cap C|} - {4\choose 4} {|A \cap B \cap C \cap D|}$$
#
# 3) ${13\choose 3} - ({4\choose 1}*{10\choose 3} - {4\choose 2}*{7\choose 3} + {4\choose 3}*{4\choose 3})$
#
#
# Ex 1.6.3
#
# $$x_1 + x_2 ... + x_5 = 13$$
#
# 1) Total count = ${{13+4} \choose 4} = {17\choose 4}$
# 2) Count # of ways where at least one $x_i \geq 4$
#
# $${5\choose 1}*{{9+4}\choose 4} - {5\choose 2}*{{5+4}\choose 4} + {5\choose 3}*{{1+4}\choose 4}$$
#
# 3) ${17\choose 4}-({5\choose 1}*{13\choose 4}-{5\choose 2}* {9\choose 4})$
#
#
# Ex 1: Dollar menu at mcdonalds has 7 items. You have $10 to spend. You plan on spending all money. How many different meals can you buy if you spend all your money and:
#
# A. Purchase at least one of each item
# 7 items $10
#
# 7-10 = 3
#
# ${3+6}\choose 6$
#
# $$9\choose 4$$
#
# B. Possibly skip some items
#
# $$16\choose 6$$
#
#
# C.
# 1) Total Count = ${{10+6}\choose 6} = {16\choose 6}$
# 2) count # of ways where you get more than 2 of any particular item
#
# 3)
# $${16\choose 6} - ({7\choose 1}*{13\choose 6} - {7\choose 2}*{10\choose 6}+ {7\choose 3}*{7\choose 6})$$
#
# {7 remaining dollars + transitions}
#
# {4 dollars + 6 transitions}
#
# {1 dollar demaining + 6 transitions}

# %% [markdown]
# # Binomial Expansions:
# term in $x^r$ = $n\choose r$ $a^{n-r}$ $b^r$

# %% [markdown]
# # Stars and Bars:
# Stars is the consistent object\
# bars are the number of changing objects - 1
#
#
# You have 7 cookies to give to 4 kids. How many ways can you do that?
#
# Ideas: \
# $4^7$ - too big because of over counting
#
# Actual:\
# Draw 7 stars which represent the 7 cookies\
# Draw 3 bars are the bins we are putting the objects in
#
# ⭐⭐⭐|⭐⭐||⭐⭐
#
# || means that that person got no cookies
#
# BBBBBBC
#
# |⭐⭐⭐⭐⭐⭐|⭐|
#
# Coutning the # of ways of distributing cookies = # of stars and bars charts with 7 ⭐ and 3 |
#
# ||⭐⭐⭐|⭐⭐⭐⭐ = $|{B^{10}_3}|$ = $10\choose 3$
#
#
# Ex: Ice-cream parlor with 10 flavors. How many milkshakes can you create with 6 scoops?\
# 6 ⭐ = Scoopes
# 9 | = Changing Flavors
#
# |⭐|⭐||⭐⭐⭐|||⭐|| = $|{B^{15}_9}|$ = $15\choose 9$
#
# Ex: How many 7 digit phone #s that are non-decreasing?
#
# stars = digits\
# bars = changing number 0-9
#
# ${B^{16}_9} = {16\choose 9}$
#
# Ex: How many integer solns to $x_1 + x_2 ... + x_5 = 13$ are there such that $x \geq 0$
#
# $$x_1 = 9 $$
# $$ x_2 = x_3 = x_4 = x_5 = 1$$
#
# stars = 1 (13)
# bars = transistions between $x_1$ (4)
#
# ${B^{17}_4} = {17\choose 4}$
#
# Ex: How many integer solns to $x_1 + x_2 ... + x_5 = 13$ are there such that $x_1,x_2,x_2 \geq 2 \land x_3,x_5 \geq 1$
#
# Give 1-3 each two 1s and $x_4,x_5 one 1$. Then equivalent probelm is to find all solns to $x_1...+x_5 = 5$
#
# We have 13 ones but we used 8 so we only have 5 left.
#
#
# 2)Using the digits 2 through 8, find the number of different 5-digit numbers such that:\
#
#     a. Digits cannot be repeated and must be written in increasing order. For example, \
#     23678 is okay, but 32678 is not.
#
# $$7\choose 5$$
#
#     b. Digits can be repeated and must be written in non-decreasing order. For example, 24448 is okay but 24484 is not.
#
# Stars = digits\
# Bars = changing number  2-8 (6)
#
# $$|B^{11}_6|$$
#
# 4)
# After gym class you are tasked with putting the 14 identical dodgeballs away into 5 bins.
#
# stars = dodgeballs\
# bars = bins
#
#     a. How many ways can you do this if there are no restrictions?8
# $$|B^{18}_4|$$
#
#     b. How many ways can you do this if each bin must contain at least one dodgeball?
#
# $14-5=9$
#
# $$|B^{13}_4|$$
#
# 5)
# How many integer solutions are there to the equation $x+y+z=8$ for which
#
# Stars = 1s that make up 8
# Bars = 2 transitions
#
#
#     a. x,y, and z are all positive?
#
# $$|B^{7}_2|$$
#
#     b. x,y, and z are all non-negative?
#
# $10\choose 2$
# $$|B^{10}_2|$$
#
#     c. x,y, and z are all greater than or equal to -3
#
# -3 from each variable
# $17+2\choose 2$
#
#
# 7)
# Your friend tells you she has 7 coins in her hand (just pennies, nickels, dimes and quarters). If you guess how many of each kind of coin she has, she will give them to you. If you guess randomly, what is the probability that you will be correct?
#
# stars = 7
# bins = 3 (4 coins)
#
# $$\frac {1} {10\choose 3}$$

# %%
from math import comb
comb(9, 3)
# Out:
# 84

# %% [markdown]
# # HW 3

# %% [markdown]
# ### <span style="color:red">Question 1:</span>
# Your wardrobe consists of 4 shirts, 2 pairs of pants, and 18 bow ties. How many different outfits can you make?
#
# You can make __ outfits.
#
# There are $4*2*18=144$ outfits. Use the multiplicative principle.

# %% [markdown]
# ### <span style="color:red">Question 2:</span>
#
# For your college interview, you must wear a tie. You own 2 regular (boring) ties and 8 (cool) bow ties.
#
# A) How many choices do you have for your neck-wear?
#
# $2+8=10$ ties. Use the additive principle.
#
# B) You realize that the interview is for clown college, so you should probably wear both a regular tie and a bow tie. How many choices do you have now?
#
# $2*8=16$ ties. Use the multiplicative principle
#
# C) For the rest of your outfit, you have 7 shirts, 5 skirts, 6 pants, and 8 dresses. You want to select either a shirt to wear with a skirt or pants, or just a dress. How many outfits do you have to choose from?
#
# $7*(5+6)+8=42$ outfits.

# %% [markdown]
# ### <span style="color:red">Question 3:</span>
#
# We usually write numbers in decimal form (or base 10), meaning numbers are composed using 10 different “digits” $\{0,1,…,9\}$. Sometimes though it is useful to write numbers hexadecimal or base 16. Now there are 16 distinct digits that can be used to form numbers: $\{0,1,…,9,A,B,C,D,E,F\}$. So for example, a 3 digit hexadecimal number might be 2B8.
#
# A) How many 6-digit hexadecimals are there in which the first digit is E or F?
#
# Here is our graphic showing the possibilities for each spot:
# $$\frac{2}{1st} *\frac{16}{2nd}*\frac{16}{3rd}...*\frac{16}{6th}$$
#
# $$OR$$
#
# $$2*16^5=2,097,152$$
#
# Since the first slot can only be E or F there are only 2 options. Each of the other 5 digits can be any of the 16 valid hexadecimal characters.
#
# B) How many 3-digit hexadecimals start with a letter (A-F) and end with a numeral (0-9)?
#
# Here is our graphic showing the possibilities for each spot:
#
# $$\frac{6}{1st}*\frac{16}{2nd}*\frac{6}{3rd}$$
#
# $$OR$$
#
# $$6*16*10=960$$
#
# The first slot only has 6 options (A-F), the second slot can be anything from (0-9 or A-F), and the third slot has 10 options (0-9)
#
# C) How many 5-digit hexadecimals start with a letter (A-F) or end with a numeral (0-9) (or both)?
#
# Here is our graphic showing the possibilities for each spot where the hexadecimal number starts with a letter (A-F):
#
# $$\frac{6}{1st} *\frac{16}{2nd}*\frac{16}{3rd}*\frac{16}{4th}*\frac{16}{5th}$$
#
# $$OR$$
#
# $$6*16^4 = 393216$$
#
# The first slot only has 6 options (A-F), the other 4 slots can be any of the 16 valid hexadecimal characters.
#
# Here is our graphic showing the possibilities for each spot where the hexadecimal number ends with a number (0-9):
#
# $$\frac{16}{1st} *\frac{16}{2nd}*\frac{16}{3rd}*\frac{16}{4th}*\frac{10}{5th}$$
#
# $$OR$$
#
# $${16^4}*10 = 655360$$
#
# The first 5 slots can be any of the 16 valid hexadecimal characters, the last slot has 10 options (0-9).
#
# We want all the elements from both these sets. However, both sets include those 5-digit hexadecimals which both start with a letter and end with a numeral $(6*{16^3}*10=245760)$ so we must subtract these (once). Thus the number of 5-digit hexadecimals starting with a letter or ending with a numeral is:
#
#
# $$PIE$$
# $$↓$$
# $$393216+655360−245760=802816$$

# %% [markdown]
# ### <span style="color:red">Question 4:</span>
#
# Suppose you have sets A and B with |A|=13 and |B|=20.
#
# What is the largest possible value for $|A\cap B|$?
#
# To maximize the number of elements in common between A and B, make $A\subset B$. This would give $|A\cap B|=13$.
#
# What is the smallest possible value for $|A\cap B|$?
#
# A and B might have no elements in common, giving  $|A\cap B|=0$
#
# What are the possible values for $|A\cap B|$?
#
#  $13\leq|A\cap B|\leq33$

# %% [markdown]
# ### <span style="color:red">Question 5:</span>
#
# If $|A|=10 $ and $ |B|=11$, what is $|A\cup B|+|A\cap B|$?
#
# $10+11-|A\cap B|=|A\cup B|$

# %% [markdown]
# ### <span style="color:red">Question 6:</span>
#
# In a recent survey, 93 students reported whether they liked their potatoes Mashed, French-fried, or Twice-baked. 32 liked them mashed, 51 liked French fried, and 54 liked twice baked potatoes. Additionally, 18 students liked both mashed and fried potatoes, 28 liked French fries and twice baked potatoes, 26 liked mashed and baked, and 13 liked all three styles. How many students hate potatoes? Explain why your answer is correct.
#
# Using the principle of inclusion/exclusion, the number of students who like their potatoes in at least one of the ways described is
#
# $$\displaystyle{32 + 51 + 54 -18 - 28 - 26 + 13 = {78}}$$
#
# Therefore there are 93−78=15 students who do not like potatoes. You can also do this problem with a Venn diagram.
#
# <center>
#     <img src="https://i.ibb.co/W67Mn8B/hated-potatoes.png" width="500" />
# </center>

# %% [markdown]
# ### <span style="color:red">Question 7:</span>
#
# Let S={1,2,3,4,5,6,7,8}
#
# How many subsets are there of cardinality 5?
#
# ${8\choose 5} = 56$
#
# S has 8 total objects and in order to make a set of size 5 we must choose 5 of them.
#
# How many subsets of cardinality 5 have {2,3,5} as a subset?
#
# ${5\choose 2} = 10$
#
# How many subsets of cardinality 5 contain at least one odd number?
#
# ${8\choose 5} = 56$
#
# How many subsets of cardinality 5 contain exactly one even number?
#
# ${4\choose 1} = 4$
